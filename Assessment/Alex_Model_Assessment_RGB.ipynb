# %% [markdown]
# # Deep Learning Project
#
# Obtention of ROC Curve and Precision Recall Curves:
#
# RGB Data

# %%
#need this to run keras with GPU
import os
os.environ['TF_XLA_FLAGS'] = '--tf_xla_enable_xla_devices'
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'
#
#Check Computer's available devices
#Will need to check in the future
import tensorflow as tf
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())

#cfg 1
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)

    except RuntimeError as e:
        print(e)

#cfg2
config = tf.compat.v1.ConfigProto(gpu_options = tf.compat.v1.GPUOptions(per_process_gpu_memory_fraction=0.8))
# device_count = {'GPU': 1})
config.gpu_options.allow_growth = True
session = tf.compat.v1.Session(config=config)
tf.compat.v1.keras.backend.set_session(session)
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 11335391923501795201
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 6698715720416463900
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 4971491488
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 11975136702336777918
# physical_device_desc: "device: 0, name: GeForce GTX 1660 Ti, pci bus id: 0000:01:00.0, compute capability: 7.5"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 3341223221397134120
# physical_device_desc: "device: XLA_GPU device"
# ]

# %%
#base libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random

import matplotlib.image as mpimg
# %matplotlib inline

from timeit import default_timer as timer



#image manipulation packages
import cv2
import os
from tqdm import tqdm
from glob import glob
from sklearn.metrics import confusion_matrix,classification_report


#Classification
from sklearn.metrics import classification_report, confusion_matrix, multilabel_confusion_matrix

sns.set()

#import keras
from tensorflow import keras
import glob
import cv2
import shutil
import random
import Augmentor


from itertools import cycle

#Data Augmentation
from keras.preprocessing.image import ImageDataGenerator

# Callbacks
from tensorflow.keras import callbacks
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import ReduceLROnPlateau

import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Flatten, Conv2D, MaxPooling2D
from keras.layers.normalization import BatchNormalization

from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score
from scipy import interp
## RESNET50

from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import callbacks

# %% [markdown]
# # 1- Import Images and Dataframe
#
# In this case, we have a folder with 1132 image - SCIAN-MorphoSpermGS folder - https://cimt.uchile.cl/gold10/. Each image is 35 x 35 pixels and has been classified by 3 experts. We will use majority vote result as target. Each image will need to be loaded and the dataset will need to be created.
#
# #### This will yield a dataset with the picture name and the label.

# %%
dataframe=pd.read_csv("Majority_Vote.csv")

# %%
os.chdir('path')
path = os.getcwd()
files = os.listdir(path)

# %%
path
# Out:
# 'C:\\Users\\Ricardo Santos\\Desktop\\Mestrado Ricardo\\Ano 1\\Spring Semester\\Deep\\Deep_Learning_Project\\CNN_SpermCells\\path'

# %%
Alex_train_datagen = ImageDataGenerator(rescale = 1./255,
                                   rotation_range = 5,
                                   width_shift_range = 0.1,
                                   height_shift_range = 0.1, 
                                   vertical_flip = True,
                                   horizontal_flip = True,
                                   brightness_range=[0.2,1.5], 
                                   fill_mode='nearest',
                                   zoom_range = 0.2,
                                   ) 

Alex_val_datagen = ImageDataGenerator(rescale = 1./255)
Alex_test_datagen = ImageDataGenerator(rescale = 1./255)

#test different color maps -  class modes and cross validation types
Alex_training = Alex_train_datagen.flow_from_directory(path+'/train',
                                                 target_size = (32, 32),
                                                 batch_size = 64,
                                                 shuffle = True,
                                                 class_mode="categorical",
                                                 color_mode = 'rgb')

Alex_val = Alex_val_datagen.flow_from_directory(path+'/val',
                                            target_size = (32, 32),
                                            batch_size = 64,
                                            shuffle = True,
                                            class_mode="categorical",
                                            color_mode = 'rgb')

Alex_test = Alex_test_datagen.flow_from_directory(path+'/test',
                                            target_size = (32, 32),
                                            batch_size = 1,
                                            shuffle = True,
                                            class_mode="categorical",
                                            color_mode = 'rgb')
# Out:
# Found 25600 images belonging to 4 classes.
# Found 383 images belonging to 4 classes.
# Found 130 images belonging to 4 classes.

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=0, verbose = 1)

es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=20, restore_best_weights = True)

checkpoint_filepath = path+'/Models/AlexNet_RGB.h5'
mc = ModelCheckpoint(
    filepath=checkpoint_filepath,
    verbose = 1,
    monitor='val_accuracy',
    mode='max',
    save_best_only=True)

class TimingCallback(keras.callbacks.Callback):
    def __init__(self, logs={}):
        self.logs=[]
    def on_epoch_begin(self, epoch, logs={}):
        self.starttime = timer()
    def on_epoch_end(self, epoch, logs={}):
        self.logs.append(timer()-self.starttime)

cb = TimingCallback()

# %% [markdown]
# #### 4.1 Preprocess input
# Online Data Augmentation  in RGB

# %% [markdown]
# #### 4.2 Build model

# %%
#Instantiation
AlexNet = Sequential()

#1st Convolutional Layer - Alexnet took 224px imgs, which we do not have here, we will adjust layers accordingly 
#by reducing first first stride and max pool. All other layers will remain the same

AlexNet.add(Conv2D(filters=96, input_shape=(32,32,3), kernel_size=(4,4), padding='same'))
AlexNet.add(BatchNormalization())
AlexNet.add(Activation('relu'))
AlexNet.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))

#2nd Convolutional Layer
AlexNet.add(Conv2D(filters=256, kernel_size=(5, 5), strides=(1,1), padding='same'))
AlexNet.add(BatchNormalization())
AlexNet.add(Activation('relu'))
AlexNet.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))

#3rd Convolutional Layer
AlexNet.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='same'))
AlexNet.add(BatchNormalization())
AlexNet.add(Activation('relu'))

#4th Convolutional Layer
AlexNet.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='same'))
AlexNet.add(BatchNormalization())
AlexNet.add(Activation('relu'))

##5th Convolutional Layer
AlexNet.add(Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), padding='same'))
AlexNet.add(BatchNormalization())
AlexNet.add(Activation('relu'))
AlexNet.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))

#Passing it to a Fully Connected layer
AlexNet.add(Flatten())

# 1st Fully Connected Layer
AlexNet.add(Dense(4096))
AlexNet.add(BatchNormalization())
AlexNet.add(Activation('relu'))

# Add Dropout to prevent overfitting
AlexNet.add(Dropout(0.4))

#2nd Fully Connected Layer
AlexNet.add(Dense(4096))
AlexNet.add(BatchNormalization())
AlexNet.add(Activation('relu'))

#Add Dropout
AlexNet.add(Dropout(0.4))

#3rd Fully Connected Layer
AlexNet.add(Dense(1024))
AlexNet.add(BatchNormalization())
AlexNet.add(Activation('relu'))
#Add Dropout
AlexNet.add(Dropout(0.4))

#Output Layer
AlexNet.add(Dense(4))
AlexNet.add(BatchNormalization())
AlexNet.add(Activation('softmax'))

#Model Summary
AlexNet.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 96)        4704
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32, 32, 96)        384
# _________________________________________________________________
# activation (Activation)      (None, 32, 32, 96)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 96)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 16, 256)       614656
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 16, 16, 256)       1024
# _________________________________________________________________
# activation_1 (Activation)    (None, 16, 16, 256)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 8, 384)         885120
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 8, 8, 384)         1536
# _________________________________________________________________
# activation_2 (Activation)    (None, 8, 8, 384)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 384)         1327488
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 8, 8, 384)         1536
# _________________________________________________________________
# activation_3 (Activation)    (None, 8, 8, 384)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 256)         884992
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 8, 8, 256)         1024
# _________________________________________________________________
# activation_4 (Activation)    (None, 8, 8, 256)         0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 4096)              0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              16781312
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 4096)              16384
# _________________________________________________________________
# activation_5 (Activation)    (None, 4096)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 4096)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 4096)              16384
# _________________________________________________________________
# activation_6 (Activation)    (None, 4096)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              4195328
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 1024)              4096
# _________________________________________________________________
# activation_7 (Activation)    (None, 1024)              0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 4)                 4100
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 4)                 16
# _________________________________________________________________
# activation_8 (Activation)    (None, 4)                 0
# =================================================================
# Total params: 41,521,396
# Trainable params: 41,500,204
# Non-trainable params: 21,192
# _________________________________________________________________

# %% [markdown]
# #### 4.3 Compile model

# %%
AlexNet.compile(loss = keras.losses.categorical_crossentropy, optimizer= 'adam', metrics=['accuracy'])

# %% [markdown]
# #### 4.4 Fit model

# %%
history = AlexNet.fit(Alex_training,
        epochs=200, 
        validation_data=Alex_val,
        verbose = 1, 
        callbacks = [mc, reduce_lr, es,cb])
# Out:
# Epoch 1/200
# 400/400 [==============================] - 29s 63ms/step - loss: 1.3521 - accuracy: 0.3281 - val_loss: 1.3517 - val_accuracy: 0.2324
#
# Epoch 00001: val_accuracy improved from -inf to 0.23238, saving model to C:\Users\Ricardo Santos\Desktop\Mestrado Ricardo\Ano 1\Spring Semester\Deep\Deep_Learning_Project\CNN_SpermCells\path/Models\AlexNet_RGB.h5
# Epoch 2/200
# 400/400 [==============================] - 24s 60ms/step - loss: 1.1921 - accuracy: 0.4473 - val_loss: 1.1543 - val_accuracy: 0.4360
#
# Epoch 00002: val_accuracy improved from 0.23238 to 0.43603, saving model to C:\Users\Ricardo Santos\Desktop\Mestrado Ricardo\Ano 1\Spring Semester\Deep\Deep_Learning_Project\CNN_SpermCells\path/Models\AlexNet_RGB.h5
# Epoch 3/200
# 400/400 [==============================] - 24s 60ms/step - loss: 1.0214 - accuracy: 0.5558 - val_loss: 0.9869 - val_accuracy: 0.5248
#
# Epoch 00003: val_accuracy improved from 0.43603 to 0.52480, saving model to C:\Users\Ricardo Santos\Desktop\Mestrado Ricardo\Ano 1\Spring Semester\Deep\Deep_Learning_Project\CNN_SpermCells\path/Models\AlexNet_RGB.h5
# Epoch 4/200
# 400/400 [==============================] - 25s 62ms/step - loss: 0.9326 - accuracy: 0.6017 - val_loss: 1.1074 - val_accuracy: 0.4909
#
# Epoch 00004: val_accuracy did not improve from 0.52480
# Epoch 5/200
# 400/400 [==============================] - 25s 63ms/step - loss: 0.8601 - accuracy: 0.6427 - val_loss: 0.9431 - val_accuracy: 0.5796
#
# Epoch 00005: val_accuracy improved from 0.52480 to 0.57963, saving model to C:\Users\Ricardo Santos\Desktop\Mestrado Ricardo\Ano 1\Spring Semester\Deep\Deep_Learning_Project\CNN_SpermCells\path/Models\AlexNet_RGB.h5
# Epoch 6/200
# 400/400 [==============================] - 25s 62ms/step - loss: 0.8267 - accuracy: 0.6565 - val_loss: 0.9033 - val_accuracy: 0.5770
#
# Epoch 00006: val_accuracy did not improve from 0.57963
# Epoch 7/200
# 400/400 [==============================] - 25s 64ms/step - loss: 0.7836 - accuracy: 0.6817 - val_loss: 1.0225 - val_accuracy: 0.5614
#
# Epoch 00007: val_accuracy did not improve from 0.57963
# Epoch 8/200
# 400/400 [==============================] - 25s 62ms/step - loss: 0.7380 - accuracy: 0.6971 - val_loss: 1.0303 - val_accuracy: 0.5483
#
# Epoch 00008: val_accuracy did not improve from 0.57963
# Epoch 9/200
# 400/400 [==============================] - 24s 61ms/step - loss: 0.7024 - accuracy: 0.7165 - val_loss: 1.1298 - val_accuracy: 0.5352
#
# Epoch 00009: val_accuracy did not improve from 0.57963
# Epoch 10/200
# 400/400 [==============================] - 24s 60ms/step - loss: 0.6766 - accuracy: 0.7261 - val_loss: 0.8478 - val_accuracy: 0.6423
#
# Epoch 00010: val_accuracy improved from 0.57963 to 0.64230, saving model to C:\Users\Ricardo Santos\Desktop\Mestrado Ricardo\Ano 1\Spring Semester\Deep\Deep_Learning_Project\CNN_SpermCells\path/Models\AlexNet_RGB.h5
# Epoch 11/200
# 400/400 [==============================] - 24s 60ms/step - loss: 0.6378 - accuracy: 0.7404 - val_loss: 1.0335 - val_accuracy: 0.5718s: 0.6378 - accuracy: 0.
#
# Epoch 00011: val_accuracy did not improve from 0.64230
# Epoch 12/200
# 400/400 [==============================] - 24s 60ms/step - loss: 0.6277 - accuracy: 0.7428 - val_loss: 0.9400 - val_accuracy: 0.5875
#
# Epoch 00012: val_accuracy did not improve from 0.64230
# Epoch 13/200
# 400/400 [==============================] - 24s 59ms/step - loss: 0.5973 - accuracy: 0.7592 - val_loss: 0.8218 - val_accuracy: 0.6632
#
# Epoch 00013: val_accuracy improved from 0.64230 to 0.66319, saving model to C:\Users\Ricardo Santos\Desktop\Mestrado Ricardo\Ano 1\Spring Semester\Deep\Deep_Learning_Project\CNN_SpermCells\path/Models\AlexNet_RGB.h5
# Epoch 14/200
# 400/400 [==============================] - 25s 61ms/step - loss: 0.5656 - accuracy: 0.7746 - val_loss: 1.0589 - val_accuracy: 0.5822
#
# Epoch 00014: val_accuracy did not improve from 0.66319
# Epoch 15/200
# 400/400 [==============================] - 25s 63ms/step - loss: 0.5403 - accuracy: 0.7813 - val_loss: 0.7811 - val_accuracy: 0.6632
#
# Epoch 00015: val_accuracy did not improve from 0.66319
# Epoch 16/200
# 400/400 [==============================] - 24s 59ms/step - loss: 0.5288 - accuracy: 0.7907 - val_loss: 0.8862 - val_accuracy: 0.6397
#
# Epoch 00016: val_accuracy did not improve from 0.66319
# Epoch 17/200
# 400/400 [==============================] - 24s 61ms/step - loss: 0.5115 - accuracy: 0.7978 - val_loss: 0.8305 - val_accuracy: 0.6867
#
# Epoch 00017: val_accuracy improved from 0.66319 to 0.68668, saving model to C:\Users\Ricardo Santos\Desktop\Mestrado Ricardo\Ano 1\Spring Semester\Deep\Deep_Learning_Project\CNN_SpermCells\path/Models\AlexNet_RGB.h5
# Epoch 18/200
# 400/400 [==============================] - 24s 60ms/step - loss: 0.4818 - accuracy: 0.8097 - val_loss: 0.8558 - val_accuracy: 0.6632
#
# Epoch 00018: val_accuracy did not improve from 0.68668
# Epoch 19/200
# 400/400 [==============================] - 24s 61ms/step - loss: 0.4655 - accuracy: 0.8189 - val_loss: 0.9903 - val_accuracy: 0.6266
#
# Epoch 00019: val_accuracy did not improve from 0.68668
# Epoch 20/200
# 400/400 [==============================] - 24s 60ms/step - loss: 0.4528 - accuracy: 0.8243 - val_loss: 0.8268 - val_accuracy: 0.6684
#
# Epoch 00020: val_accuracy did not improve from 0.68668
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 21/200
# 400/400 [==============================] - 24s 59ms/step - loss: 0.3870 - accuracy: 0.8577 - val_loss: 0.8648 - val_accuracy: 0.6841
#
# Epoch 00021: val_accuracy did not improve from 0.68668
# Epoch 22/200
# 400/400 [==============================] - 24s 60ms/step - loss: 0.3492 - accuracy: 0.8684 - val_loss: 0.9272 - val_accuracy: 0.6919
#
# Epoch 00022: val_accuracy improved from 0.68668 to 0.69191, saving model to C:\Users\Ricardo Santos\Desktop\Mestrado Ricardo\Ano 1\Spring Semester\Deep\Deep_Learning_Project\CNN_SpermCells\path/Models\AlexNet_RGB.h5
# Epoch 23/200
# 400/400 [==============================] - 25s 62ms/step - loss: 0.3334 - accuracy: 0.8738 - val_loss: 0.8742 - val_accuracy: 0.7076
#
# Epoch 00023: val_accuracy improved from 0.69191 to 0.70757, saving model to C:\Users\Ricardo Santos\Desktop\Mestrado Ricardo\Ano 1\Spring Semester\Deep\Deep_Learning_Project\CNN_SpermCells\path/Models\AlexNet_RGB.h5
# Epoch 24/200
# 400/400 [==============================] - 25s 61ms/step - loss: 0.3201 - accuracy: 0.8813 - val_loss: 0.9116 - val_accuracy: 0.6997
#
# Epoch 00024: val_accuracy did not improve from 0.70757
# Epoch 25/200
# 400/400 [==============================] - 25s 62ms/step - loss: 0.3065 - accuracy: 0.8842 - val_loss: 0.9551 - val_accuracy: 0.6893
#
# Epoch 00025: val_accuracy did not improve from 0.70757
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 26/200
# 400/400 [==============================] - 25s 62ms/step - loss: 0.2795 - accuracy: 0.8979 - val_loss: 0.8959 - val_accuracy: 0.7285
#
# Epoch 00026: val_accuracy improved from 0.70757 to 0.72846, saving model to C:\Users\Ricardo Santos\Desktop\Mestrado Ricardo\Ano 1\Spring Semester\Deep\Deep_Learning_Project\CNN_SpermCells\path/Models\AlexNet_RGB.h5
# Epoch 27/200
# 400/400 [==============================] - 24s 59ms/step - loss: 0.2587 - accuracy: 0.9059 - val_loss: 0.9941 - val_accuracy: 0.6762
#
# Epoch 00027: val_accuracy did not improve from 0.72846
# Epoch 28/200
# 400/400 [==============================] - 24s 61ms/step - loss: 0.2492 - accuracy: 0.9088 - val_loss: 1.0051 - val_accuracy: 0.6710
#
# Epoch 00028: val_accuracy did not improve from 0.72846
# Epoch 29/200
# 400/400 [==============================] - 25s 62ms/step - loss: 0.2356 - accuracy: 0.9137 - val_loss: 0.9538 - val_accuracy: 0.7076
#
# Epoch 00029: val_accuracy did not improve from 0.72846
# Epoch 30/200
# 400/400 [==============================] - 25s 62ms/step - loss: 0.2336 - accuracy: 0.9158 - val_loss: 1.0051 - val_accuracy: 0.6919
#
# Epoch 00030: val_accuracy did not improve from 0.72846
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 31/200
# 400/400 [==============================] - 25s 61ms/step - loss: 0.2165 - accuracy: 0.9221 - val_loss: 1.0007 - val_accuracy: 0.6736
#
# Epoch 00031: val_accuracy did not improve from 0.72846
# Epoch 32/200
# 400/400 [==============================] - 24s 60ms/step - loss: 0.2066 - accuracy: 0.9258 - val_loss: 1.0230 - val_accuracy: 0.6789
#
# Epoch 00032: val_accuracy did not improve from 0.72846
# Epoch 33/200
# 400/400 [==============================] - 25s 62ms/step - loss: 0.2032 - accuracy: 0.9277 - val_loss: 1.0119 - val_accuracy: 0.7128
#
# Epoch 00033: val_accuracy did not improve from 0.72846
# Epoch 34/200
# 400/400 [==============================] - 25s 62ms/step - loss: 0.1988 - accuracy: 0.9282 - val_loss: 1.0208 - val_accuracy: 0.6997
#
# Epoch 00034: val_accuracy did not improve from 0.72846
# Epoch 35/200
# 400/400 [==============================] - 24s 60ms/step - loss: 0.1846 - accuracy: 0.9361 - val_loss: 1.0480 - val_accuracy: 0.7050
#
# Epoch 00035: val_accuracy did not improve from 0.72846
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Restoring model weights from the end of the best epoch.
# Epoch 00035: early stopping

# %% [markdown]
# #### 4.5 Evaluate  model

# %%
_, train_acc = AlexNet.evaluate(Alex_training, verbose=1)
_, val_acc = AlexNet.evaluate(Alex_val, verbose=1)
print('Train: %.3f, Val: %.3f' % (train_acc, val_acc))

# plot training history
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='val')
plt.legend()
plt.show()
# Out:
# 400/400 [==============================] - 23s 58ms/step - loss: 0.5361 - accuracy: 0.7877
# 6/6 [==============================] - 0s 29ms/step - loss: 0.7811 - accuracy: 0.6632
# Train: 0.788, Val: 0.663

# %%
test_loss, test_acc = AlexNet.evaluate(Alex_test)

print('Test loss:', test_loss)
print('Test accuracy:', test_acc)
print("\nTime:",sum(cb.logs)/60,"min")
# Out:
# 130/130 [==============================] - 1s 6ms/step - loss: 0.9195 - accuracy: 0.6769
# Test loss: 0.9195476770401001
# Test accuracy: 0.6769230961799622
#
# Time: 14.500982403333335 min

# %% [markdown]
# #### 4.5 Make Predictions

# %%
#get predicted probality
prediction = AlexNet.predict(Alex_test,verbose=1)

#Get class of prediction
predicted_class = np.argmax(prediction,axis=1)

#get trueclass
true_classes = Alex_test.classes

# get names of pictures
filenames = Alex_test.filenames

#store info in dataframe
alex_predictions = pd.DataFrame({'Filename': filenames, 'Label': true_classes, 'AlexNet': predicted_class})
# Out:
# 130/130 [==============================] - 1s 4ms/step

# %%
Alex_pred =  pd.DataFrame(prediction, columns = ['Class 0', 'Class 1', 'Class 2', 'Class 3'], index = filenames)

Alex_pred.to_csv(path+'/Models/Alex_pred_prob.csv')

Alex_pred
# Out:
#                                          Class 0   Class 1   Class 2   Class 3
# class0\ch00_p1-pl2-sample10-sperm1.tif  0.948946  0.007618  0.008862  0.034574
# class0\ch00_p1-pl2-sample10-sperm4.tif  0.008858  0.066223  0.021957  0.902961
# class0\ch00_p1-pl2-sample12-sperm9.tif  0.001931  0.006779  0.977952  0.013338
# class0\ch00_p1-pl2-sample5-sperm3.tif   0.060169  0.040038  0.042529  0.857264
# class0\ch00_p1-pl3-sample14-sperm3.tif  0.029355  0.026549  0.005771  0.938325
# ...                                          ...       ...       ...       ...
# class3\ch00_p5-pl1-sample9-sperm5.tif   0.004506  0.033726  0.008031  0.953737
# class3\image_010.BMP                    0.001036  0.000514  0.000315  0.998135
# class3\image_013.BMP                    0.005654  0.022767  0.868098  0.103482
# class3\image_014.BMP                    0.009293  0.551320  0.028320  0.411068
# class3\image_021.BMP                    0.003014  0.460609  0.003336  0.533042
#
# [130 rows x 4 columns]

# %%
alex_predictions
# Out:
#                                    Filename  Label  AlexNet
# 0    class0\ch00_p1-pl2-sample10-sperm1.tif      0        0
# 1    class0\ch00_p1-pl2-sample10-sperm4.tif      0        3
# 2    class0\ch00_p1-pl2-sample12-sperm9.tif      0        2
# 3     class0\ch00_p1-pl2-sample5-sperm3.tif      0        3
# 4    class0\ch00_p1-pl3-sample14-sperm3.tif      0        3
# ..                                      ...    ...      ...
# 125   class3\ch00_p5-pl1-sample9-sperm5.tif      3        3
# 126                    class3\image_010.BMP      3        3
# 127                    class3\image_013.BMP      3        2
# 128                    class3\image_014.BMP      3        1
# 129                    class3\image_021.BMP      3        3
#
# [130 rows x 3 columns]

# %% [markdown]
# #### 4.7  Confusion matrix and classification report

# %%
def metrics(y_train, pred_train , y_val, pred_val):
    print('___________________________________________________________________________________________________________')
    print('                                                     TRAIN                                                 ')
    print('----------------------------------------------------------------------------------------------------------')
    print(classification_report(y_train, pred_train))
    print(confusion_matrix(y_train, pred_train))


    print('___________________________________________________________________________________________________________')
    print('                                                VALIDATION                                                 ')
    print('-----------------------------------------------------------------------------------------------------------')
    print(classification_report(y_val, pred_val))
    print(confusion_matrix(y_val, pred_val))

# %%
train_labels, val_labels = Alex_training.classes, Alex_val.classes
pred_train, pred_val = np.argmax(AlexNet.predict(Alex_training), axis = 1), np.argmax(AlexNet.predict(Alex_val), axis = 1)

metrics(train_labels, pred_train , val_labels, pred_val)
# Out:
# ___________________________________________________________________________________________________________
#                                                      TRAIN
# ----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.25      0.26      0.25      6400
#            1       0.25      0.24      0.24      6400
#            2       0.25      0.22      0.23      6400
#            3       0.25      0.26      0.26      6400
#
#     accuracy                           0.25     25600
#    macro avg       0.25      0.25      0.25     25600
# weighted avg       0.25      0.25      0.25     25600
#
# [[1646 1617 1406 1731]
#  [1662 1545 1508 1685]
#  [1698 1561 1423 1718]
#  [1683 1560 1466 1691]]
# ___________________________________________________________________________________________________________
#                                                 VALIDATION
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.12      0.15      0.13        46
#            1       0.25      0.19      0.21        84
#            2       0.17      0.17      0.17        40
#            3       0.57      0.59      0.58       213
#
#     accuracy                           0.40       383
#    macro avg       0.28      0.28      0.28       383
# weighted avg       0.40      0.40      0.40       383
#
# [[  7   7   4  28]
#  [ 15  16   7  46]
#  [  8   4   7  21]
#  [ 28  38  22 125]]

# %%
class_labels = list(Alex_test.class_indices.keys())   

print(confusion_matrix(true_classes, predicted_class))

report = classification_report(true_classes, predicted_class, target_names=class_labels)
print(report)
# Out:
# [[ 3  3  2  8]
#  [ 4  7  2 16]
#  [ 2  0  0 12]
#  [11 11 12 37]]
#               precision    recall  f1-score   support
#
#       class0       0.15      0.19      0.17        16
#       class1       0.33      0.24      0.28        29
#       class2       0.00      0.00      0.00        14
#       class3       0.51      0.52      0.51        71
#
#     accuracy                           0.36       130
#    macro avg       0.25      0.24      0.24       130
# weighted avg       0.37      0.36      0.36       130

# %% [markdown]
# ### ROC CURVES AND PRECISION RECALL

# %%
#VAL DATA

y_pred = AlexNet.predict(Alex_val)
y_real = val_labels

# %%
from sklearn.preprocessing import label_binarize
# Binarize the output
y_real = label_binarize(y_real, classes=[0, 1, 2, 3])
#y_pred = label_binarize(y_pred, classes=[0, 1, 2, 3])
n_classes = y_real.shape[1]

# %%
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(4):
    fpr[i], tpr[i], _ = roc_curve(y_real[:, i], y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_real.ravel(), y_pred.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# %%
lw=2


# First aggregate all false positive rates
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

# Plot all ROC curves
plt.rcParams.update({'font.size': 16})
plt.figure(figsize=(8, 8))
plt.plot(fpr["micro"], tpr["micro"],
         label='micro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["micro"]),
         color='deeppink', linestyle=':', linewidth=4)

#plt.plot(fpr["macro"], tpr["macro"],
         #label='macro-average ROC curve (area = {0:0.2f})'
               #''.format(roc_auc["macro"]),
         #color='navy', linestyle=':', linewidth=4)

colors = cycle(['navy', 'turquoise', 'darkorange', 'cornflowerblue', 'teal'])

for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc="lower right")
plt.legend(loc=(1.2, 0.67), prop=dict(size=14), frameon=False)

#make it pretty
for pos in ['right', 'top']:
    plt.gca().spines[pos].set_visible(False)

plt.show()
# Out:
# <ipython-input-22-70844e3c8198>:10: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
#   mean_tpr += interp(all_fpr, fpr[i], tpr[i])

# %%
#PRecision Recall

# For each class
precision = dict()
recall = dict()
average_precision = dict()
for i in range(n_classes):
    precision[i], recall[i], _ = precision_recall_curve(y_real[:, i],
                                                        y_pred[:, i])
    average_precision[i] = average_precision_score(y_real[:, i], y_pred[:, i])

# A "micro-average": quantifying score on all classes jointly
precision["micro"], recall["micro"], _ = precision_recall_curve(y_real.ravel(), y_pred.ravel())
average_precision["micro"] = average_precision_score(y_real, y_pred,
                                                     average="micro")
print('Average precision score, micro-averaged over all classes: {0:0.2f}'
      .format(average_precision["micro"]))
# Out:
# Average precision score, micro-averaged over all classes: 0.36

# %%
# setup plot details
colors = cycle(['navy', 'turquoise', 'darkorange', 'cornflowerblue', 'teal'])

plt.figure(figsize=(8, 8))
f_scores = np.linspace(0.2, 0.8, num=4)
lines = []
labels = []
for f_score in f_scores:
    x = np.linspace(0.01, 1)
    y = f_score * x / (2 * x - f_score)
    l, = plt.plot(x[y >= 0], y[y >= 0], color='gray', alpha=0.2)
    plt.annotate('f1={0:0.1f}'.format(f_score), xy=(0.9, y[45] + 0.02))

lines.append(l)
labels.append('iso-f1 curves')
l, = plt.plot(recall["micro"], precision["micro"], color='gold', lw=2)
lines.append(l)
labels.append('micro-average Precision-recall (area = {0:0.2f})'
              ''.format(average_precision["micro"]))

for i, color in zip(range(n_classes), colors):
    l, = plt.plot(recall[i], precision[i], color=color, lw=2)
    lines.append(l)
    labels.append('Precision-recall for class {0} (area = {1:0.2f})'.format(i, average_precision[i]))
    
#plot
fig = plt.gcf()
fig.subplots_adjust(bottom=0.25)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('Recall (Positive Predictive Value)')
plt.ylabel('Precision (True Positive Rate)')
plt.title('Precision-Recall Curve')
plt.legend(lines, labels, loc=(1, 0.67), prop=dict(size=14), frameon=False)

#make it pretty
for pos in ['right', 'top']:
    plt.gca().spines[pos].set_visible(False)


plt.show()

# %% [markdown]
# ## Test Data

# %%
#VAL DATA

y_pred = prediction
y_real = true_classes

# %%
from sklearn.preprocessing import label_binarize
# Binarize the output
y_real = label_binarize(y_real, classes=[0, 1, 2, 3])
#y_pred = label_binarize(y_pred, classes=[0, 1, 2, 3])
n_classes = y_real.shape[1]

# %%
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(4):
    fpr[i], tpr[i], _ = roc_curve(y_real[:, i], y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_real.ravel(), y_pred.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# %%
lw=2


# First aggregate all false positive rates
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

# Plot all ROC curves
plt.rcParams.update({'font.size': 16})
plt.figure(figsize=(8, 8))
plt.plot(fpr["micro"], tpr["micro"],
         label='micro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["micro"]),
         color='deeppink', linestyle=':', linewidth=4)

#plt.plot(fpr["macro"], tpr["macro"],
         #label='macro-average ROC curve (area = {0:0.2f})'
               #''.format(roc_auc["macro"]),
         #color='navy', linestyle=':', linewidth=4)

colors = cycle(['navy', 'turquoise', 'darkorange', 'cornflowerblue', 'teal'])

for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc="lower right")
plt.legend(loc=(1.2, 0.67), prop=dict(size=14), frameon=False)

#make it pretty
for pos in ['right', 'top']:
    plt.gca().spines[pos].set_visible(False)

plt.show()
# Out:
# <ipython-input-28-70844e3c8198>:10: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
#   mean_tpr += interp(all_fpr, fpr[i], tpr[i])

# %% [markdown]
# ### Precision-Recall Curve

# %%
#PRecision Recall

# For each class
precision = dict()
recall = dict()
average_precision = dict()
for i in range(n_classes):
    precision[i], recall[i], _ = precision_recall_curve(y_real[:, i],
                                                        y_pred[:, i])
    average_precision[i] = average_precision_score(y_real[:, i], y_pred[:, i])

# A "micro-average": quantifying score on all classes jointly
precision["micro"], recall["micro"], _ = precision_recall_curve(y_real.ravel(), y_pred.ravel())
average_precision["micro"] = average_precision_score(y_real, y_pred,
                                                     average="micro")
print('Average precision score, micro-averaged over all classes: {0:0.2f}'
      .format(average_precision["micro"]))
# Out:
# Average precision score, micro-averaged over all classes: 0.35

# %%
# setup plot details
colors = cycle(['navy', 'turquoise', 'darkorange', 'cornflowerblue', 'teal'])

plt.figure(figsize=(8, 8))
f_scores = np.linspace(0.2, 0.8, num=4)
lines = []
labels = []
for f_score in f_scores:
    x = np.linspace(0.01, 1)
    y = f_score * x / (2 * x - f_score)
    l, = plt.plot(x[y >= 0], y[y >= 0], color='gray', alpha=0.2)
    plt.annotate('f1={0:0.1f}'.format(f_score), xy=(0.9, y[45] + 0.02))

lines.append(l)
labels.append('iso-f1 curves')
l, = plt.plot(recall["micro"], precision["micro"], color='gold', lw=2)
lines.append(l)
labels.append('micro-average Precision-recall (area = {0:0.2f})'
              ''.format(average_precision["micro"]))

for i, color in zip(range(n_classes), colors):
    l, = plt.plot(recall[i], precision[i], color=color, lw=2)
    lines.append(l)
    labels.append('Precision-recall for class {0} (area = {1:0.2f})'.format(i, average_precision[i]))
    
#plot
fig = plt.gcf()
fig.subplots_adjust(bottom=0.25)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('Recall (Positive Predictive Value)')
plt.ylabel('Precision (True Positive Rate)')
plt.title('Precision-Recall Curve')
plt.legend(lines, labels, loc=(1, 0.67), prop=dict(size=14), frameon=False)

#make it pretty
for pos in ['right', 'top']:
    plt.gca().spines[pos].set_visible(False)


plt.show()
