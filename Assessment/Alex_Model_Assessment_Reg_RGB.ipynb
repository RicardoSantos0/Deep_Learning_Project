# %% [markdown]
# # Deep Learning Project
#
# Obtention of ROC Curve and Precision Recall Curves:
#
# RGB Data

# %%
#need this to run keras with GPU
import os
os.environ['TF_XLA_FLAGS'] = '--tf_xla_enable_xla_devices'
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'
#
#Check Computer's available devices
#Will need to check in the future
import tensorflow as tf
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())

#cfg 1
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)

    except RuntimeError as e:
        print(e)

#cfg2
config = tf.compat.v1.ConfigProto(gpu_options = tf.compat.v1.GPUOptions(per_process_gpu_memory_fraction=0.8))
# device_count = {'GPU': 1})
config.gpu_options.allow_growth = True
session = tf.compat.v1.Session(config=config)
tf.compat.v1.keras.backend.set_session(session)
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 11254816259347250842
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 11678649840081479173
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 4971491488
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 8537698839679232179
# physical_device_desc: "device: 0, name: GeForce GTX 1660 Ti, pci bus id: 0000:01:00.0, compute capability: 7.5"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 5236195177750423884
# physical_device_desc: "device: XLA_GPU device"
# ]

# %%
#base libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random

import matplotlib.image as mpimg
# %matplotlib inline

from timeit import default_timer as timer



#image manipulation packages
import cv2
import os
from tqdm import tqdm
from glob import glob
from sklearn.metrics import confusion_matrix,classification_report


#Classification
from sklearn.metrics import classification_report, confusion_matrix, multilabel_confusion_matrix

sns.set()

#import keras
from tensorflow import keras
import glob
import cv2
import shutil
import random
import Augmentor


from itertools import cycle

#Data Augmentation
from keras.preprocessing.image import ImageDataGenerator

# Callbacks
from tensorflow.keras import callbacks
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import ReduceLROnPlateau

import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Flatten, Conv2D, MaxPooling2D
from keras.layers.normalization import BatchNormalization

from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score
from scipy import interp
## RESNET50

from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import callbacks

# %% [markdown]
# # 1- Import Images and Dataframe
#
# In this case, we have a folder with 1132 image - SCIAN-MorphoSpermGS folder - https://cimt.uchile.cl/gold10/. Each image is 35 x 35 pixels and has been classified by 3 experts. We will use majority vote result as target. Each image will need to be loaded and the dataset will need to be created.
#
# #### This will yield a dataset with the picture name and the label.

# %%
dataframe=pd.read_csv("Majority_Vote.csv")

# %%
os.chdir('path')
path = os.getcwd()
files = os.listdir(path)

# %%
path
# Out:
# 'C:\\Users\\Ricardo Santos\\Desktop\\Mestrado Ricardo\\Ano 1\\Spring Semester\\Deep\\Deep_Learning_Project\\CNN_SpermCells\\path'

# %%
Alex_train_datagen = ImageDataGenerator(rescale = 1./255,
                                   rotation_range = 5,
                                   width_shift_range = 0.1,
                                   height_shift_range = 0.1, 
                                   vertical_flip = True,
                                   horizontal_flip = True,
                                   brightness_range=[0.2,1.5], 
                                   fill_mode='nearest',
                                   zoom_range = 0.2,
                                   ) 

Alex_val_datagen = ImageDataGenerator(rescale = 1./255)
Alex_test_datagen = ImageDataGenerator(rescale = 1./255)

#test different color maps -  class modes and cross validation types
Alex_training = Alex_train_datagen.flow_from_directory(path+'/train',
                                                 target_size = (32, 32),
                                                 batch_size = 64,
                                                 shuffle = True,
                                                 class_mode="categorical",
                                                 color_mode = 'rgb')

Alex_val = Alex_val_datagen.flow_from_directory(path+'/val',
                                            target_size = (32, 32),
                                            batch_size = 64,
                                            shuffle = True,
                                            class_mode="categorical",
                                            color_mode = 'rgb')

Alex_test = Alex_test_datagen.flow_from_directory(path+'/test',
                                            target_size = (32, 32),
                                            batch_size = 1,
                                            shuffle = True,
                                            class_mode="categorical",
                                            color_mode = 'rgb')
# Out:
# Found 25600 images belonging to 4 classes.
# Found 383 images belonging to 4 classes.
# Found 130 images belonging to 4 classes.

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=0, verbose = 1)

es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=20, restore_best_weights = True)

checkpoint_filepath = path+'/Models/AlexNet_RGB.h5'
mc = ModelCheckpoint(
    filepath=checkpoint_filepath,
    verbose = 1,
    monitor='val_accuracy',
    mode='max',
    save_best_only=True)

class TimingCallback(keras.callbacks.Callback):
    def __init__(self, logs={}):
        self.logs=[]
    def on_epoch_begin(self, epoch, logs={}):
        self.starttime = timer()
    def on_epoch_end(self, epoch, logs={}):
        self.logs.append(timer()-self.starttime)

cb = TimingCallback()
logs = keras.callbacks.TensorBoard(log_dir='./logs', write_graph=True, write_images= True)

# %% [markdown]
# #### 4.1 Preprocess input
# Online Data Augmentation  in RGB

# %% [markdown]
# #### 4.2 Build model

# %%
#Instantiation
AlexNet = Sequential()

#1st Convolutional Layer - Alexnet took 224px imgs, which we do not have here, we will adjust layers accordingly 
#by reducing first first stride and max pool. All other layers will remain the same

AlexNet.add(Conv2D(filters=96, input_shape=(32,32,3), kernel_size=(4,4), padding='same', kernel_regularizer =keras.regularizers.l2( l=0.01)))
AlexNet.add(BatchNormalization())
AlexNet.add(Activation('relu'))
AlexNet.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))

#2nd Convolutional Layer
AlexNet.add(Conv2D(filters=256, kernel_size=(5, 5), strides=(1,1), padding='same', kernel_regularizer =keras.regularizers.l2( l=0.01)))
AlexNet.add(BatchNormalization())
AlexNet.add(Activation('relu'))
AlexNet.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))

#3rd Convolutional Layer
AlexNet.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='same', kernel_regularizer =keras.regularizers.l2( l=0.01)))
AlexNet.add(BatchNormalization())
AlexNet.add(Activation('relu'))

#4th Convolutional Layer
AlexNet.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='same', kernel_regularizer =keras.regularizers.l2( l=0.01)))
AlexNet.add(BatchNormalization())
AlexNet.add(Activation('relu'))

##5th Convolutional Layer
AlexNet.add(Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), padding='same', kernel_regularizer =keras.regularizers.l2( l=0.01)))
AlexNet.add(BatchNormalization())
AlexNet.add(Activation('relu'))
AlexNet.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))

#Passing it to a Fully Connected layer
AlexNet.add(Flatten())

# 1st Fully Connected Layer
AlexNet.add(Dense(4096))
AlexNet.add(BatchNormalization())
AlexNet.add(Activation('relu'))

# Add Dropout to prevent overfitting
AlexNet.add(Dropout(0.4))

#2nd Fully Connected Layer
AlexNet.add(Dense(4096))
AlexNet.add(BatchNormalization())
AlexNet.add(Activation('relu'))

#Add Dropout
AlexNet.add(Dropout(0.4))

#3rd Fully Connected Layer
AlexNet.add(Dense(1024))
AlexNet.add(BatchNormalization())
AlexNet.add(Activation('relu'))
#Add Dropout
AlexNet.add(Dropout(0.4))

#Output Layer
AlexNet.add(Dense(4))
AlexNet.add(BatchNormalization())
AlexNet.add(Activation('softmax'))

#Model Summary
AlexNet.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 96)        4704
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32, 32, 96)        384
# _________________________________________________________________
# activation (Activation)      (None, 32, 32, 96)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 96)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 16, 256)       614656
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 16, 16, 256)       1024
# _________________________________________________________________
# activation_1 (Activation)    (None, 16, 16, 256)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 8, 384)         885120
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 8, 8, 384)         1536
# _________________________________________________________________
# activation_2 (Activation)    (None, 8, 8, 384)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 384)         1327488
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 8, 8, 384)         1536
# _________________________________________________________________
# activation_3 (Activation)    (None, 8, 8, 384)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 256)         884992
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 8, 8, 256)         1024
# _________________________________________________________________
# activation_4 (Activation)    (None, 8, 8, 256)         0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 4096)              0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              16781312
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 4096)              16384
# _________________________________________________________________
# activation_5 (Activation)    (None, 4096)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 4096)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 4096)              16384
# _________________________________________________________________
# activation_6 (Activation)    (None, 4096)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              4195328
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 1024)              4096
# _________________________________________________________________
# activation_7 (Activation)    (None, 1024)              0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 4)                 4100
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 4)                 16
# _________________________________________________________________
# activation_8 (Activation)    (None, 4)                 0
# =================================================================
# Total params: 41,521,396
# Trainable params: 41,500,204
# Non-trainable params: 21,192
# _________________________________________________________________

# %% [markdown]
# #### 4.3 Compile model

# %%
AlexNet.compile(loss = keras.losses.categorical_crossentropy, optimizer= 'adam', metrics=['accuracy'])

# %% [markdown]
# #### 4.4 Fit model

# %%
history = AlexNet.fit(Alex_training,
        epochs=200, 
        validation_data=Alex_val,
        verbose = 1, 
        callbacks = [mc, reduce_lr, es,cb, logs])
# Out:
# Epoch 1/200
# 400/400 [==============================] - 120s 287ms/step - loss: 6.2475 - accuracy: 0.3308 - val_loss: 1.7819 - val_accuracy: 0.0966
#
# Epoch 00001: val_accuracy improved from -inf to 0.09661, saving model to C:\Users\Ricardo Santos\Desktop\Mestrado Ricardo\Ano 1\Spring Semester\Deep\Deep_Learning_Project\CNN_SpermCells\path/Models\AlexNet_RGB.h5
# Epoch 2/200
# 400/400 [==============================] - 87s 218ms/step - loss: 1.3789 - accuracy: 0.3740 - val_loss: 1.4114 - val_accuracy: 0.3943
#
# Epoch 00002: val_accuracy improved from 0.09661 to 0.39426, saving model to C:\Users\Ricardo Santos\Desktop\Mestrado Ricardo\Ano 1\Spring Semester\Deep\Deep_Learning_Project\CNN_SpermCells\path/Models\AlexNet_RGB.h5
# Epoch 3/200
# 400/400 [==============================] - 100s 251ms/step - loss: 1.3795 - accuracy: 0.3836 - val_loss: 1.4747 - val_accuracy: 0.2245
#
# Epoch 00003: val_accuracy did not improve from 0.39426
# Epoch 4/200
# 400/400 [==============================] - 103s 258ms/step - loss: 1.3910 - accuracy: 0.3905 - val_loss: 1.4285 - val_accuracy: 0.2480
#
# Epoch 00004: val_accuracy did not improve from 0.39426
# Epoch 5/200
# 400/400 [==============================] - 99s 247ms/step - loss: 1.3896 - accuracy: 0.4032 - val_loss: 1.4534 - val_accuracy: 0.3655
#
# Epoch 00005: val_accuracy did not improve from 0.39426
# Epoch 6/200
# 400/400 [==============================] - 105s 262ms/step - loss: 1.4281 - accuracy: 0.3977 - val_loss: 1.4551 - val_accuracy: 0.2742
#
# Epoch 00006: val_accuracy did not improve from 0.39426
# Epoch 7/200
# 400/400 [==============================] - 103s 257ms/step - loss: 1.3955 - accuracy: 0.4069 - val_loss: 1.4819 - val_accuracy: 0.3107
#
# Epoch 00007: val_accuracy did not improve from 0.39426
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 8/200
# 400/400 [==============================] - 110s 276ms/step - loss: 1.3368 - accuracy: 0.4312 - val_loss: 1.3777 - val_accuracy: 0.3734
#
# Epoch 00008: val_accuracy did not improve from 0.39426
# Epoch 9/200
# 400/400 [==============================] - 106s 265ms/step - loss: 1.3154 - accuracy: 0.4383 - val_loss: 1.4919 - val_accuracy: 0.2507
#
# Epoch 00009: val_accuracy did not improve from 0.39426
# Epoch 10/200
# 400/400 [==============================] - 106s 265ms/step - loss: 1.3214 - accuracy: 0.4502 - val_loss: 3.1222 - val_accuracy: 0.1201
#
# Epoch 00010: val_accuracy did not improve from 0.39426
# Epoch 11/200
# 400/400 [==============================] - 106s 265ms/step - loss: 1.3100 - accuracy: 0.4579 - val_loss: 1.5148 - val_accuracy: 0.2924
#
# Epoch 00011: val_accuracy did not improve from 0.39426
# Epoch 12/200
# 400/400 [==============================] - 110s 275ms/step - loss: 1.2902 - accuracy: 0.4641 - val_loss: 1.3167 - val_accuracy: 0.4569
#
# Epoch 00012: val_accuracy improved from 0.39426 to 0.45692, saving model to C:\Users\Ricardo Santos\Desktop\Mestrado Ricardo\Ano 1\Spring Semester\Deep\Deep_Learning_Project\CNN_SpermCells\path/Models\AlexNet_RGB.h5
# Epoch 13/200
# 400/400 [==============================] - 107s 267ms/step - loss: 1.2750 - accuracy: 0.4715 - val_loss: 1.3487 - val_accuracy: 0.2898
#
# Epoch 00013: val_accuracy did not improve from 0.45692
# Epoch 14/200
# 400/400 [==============================] - 106s 265ms/step - loss: 1.2438 - accuracy: 0.4955 - val_loss: 1.3809 - val_accuracy: 0.3185
#
# Epoch 00014: val_accuracy did not improve from 0.45692
# Epoch 15/200
# 400/400 [==============================] - 107s 268ms/step - loss: 1.2380 - accuracy: 0.5007 - val_loss: 1.1796 - val_accuracy: 0.5170
#
# Epoch 00015: val_accuracy improved from 0.45692 to 0.51697, saving model to C:\Users\Ricardo Santos\Desktop\Mestrado Ricardo\Ano 1\Spring Semester\Deep\Deep_Learning_Project\CNN_SpermCells\path/Models\AlexNet_RGB.h5
# Epoch 16/200
# 400/400 [==============================] - 112s 279ms/step - loss: 1.2257 - accuracy: 0.5006 - val_loss: 1.3595 - val_accuracy: 0.3629
#
# Epoch 00016: val_accuracy did not improve from 0.51697
# Epoch 17/200
# 400/400 [==============================] - 107s 268ms/step - loss: 1.2038 - accuracy: 0.5095 - val_loss: 1.2545 - val_accuracy: 0.4178
#
# Epoch 00017: val_accuracy did not improve from 0.51697
# Epoch 18/200
# 400/400 [==============================] - 110s 274ms/step - loss: 1.1716 - accuracy: 0.5293 - val_loss: 1.1889 - val_accuracy: 0.4595
#
# Epoch 00018: val_accuracy did not improve from 0.51697
# Epoch 19/200
# 400/400 [==============================] - 117s 293ms/step - loss: 1.1618 - accuracy: 0.5452 - val_loss: 1.2324 - val_accuracy: 0.4595
#
# Epoch 00019: val_accuracy did not improve from 0.51697
# Epoch 20/200
# 400/400 [==============================] - 127s 318ms/step - loss: 1.1469 - accuracy: 0.5507 - val_loss: 1.2524 - val_accuracy: 0.4204
#
# Epoch 00020: val_accuracy did not improve from 0.51697
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 21/200
# 400/400 [==============================] - 128s 319ms/step - loss: 1.0598 - accuracy: 0.5847 - val_loss: 1.2983 - val_accuracy: 0.4256
#
# Epoch 00021: val_accuracy did not improve from 0.51697
# Epoch 22/200
# 400/400 [==============================] - 124s 310ms/step - loss: 1.0057 - accuracy: 0.6072 - val_loss: 1.2128 - val_accuracy: 0.4465
#
# Epoch 00022: val_accuracy did not improve from 0.51697
# Epoch 23/200
# 400/400 [==============================] - 131s 327ms/step - loss: 1.0065 - accuracy: 0.6049 - val_loss: 1.4269 - val_accuracy: 0.3969
#
# Epoch 00023: val_accuracy did not improve from 0.51697
# Epoch 24/200
# 400/400 [==============================] - 126s 314ms/step - loss: 0.9627 - accuracy: 0.6301 - val_loss: 1.0746 - val_accuracy: 0.5326
#
# Epoch 00024: val_accuracy improved from 0.51697 to 0.53264, saving model to C:\Users\Ricardo Santos\Desktop\Mestrado Ricardo\Ano 1\Spring Semester\Deep\Deep_Learning_Project\CNN_SpermCells\path/Models\AlexNet_RGB.h5
# Epoch 25/200
# 400/400 [==============================] - 118s 295ms/step - loss: 0.9457 - accuracy: 0.6363 - val_loss: 0.9485 - val_accuracy: 0.6084
#
# Epoch 00025: val_accuracy improved from 0.53264 to 0.60836, saving model to C:\Users\Ricardo Santos\Desktop\Mestrado Ricardo\Ano 1\Spring Semester\Deep\Deep_Learning_Project\CNN_SpermCells\path/Models\AlexNet_RGB.h5
# Epoch 26/200
# 400/400 [==============================] - 121s 303ms/step - loss: 0.9372 - accuracy: 0.6378 - val_loss: 1.0122 - val_accuracy: 0.5509
#
# Epoch 00026: val_accuracy did not improve from 0.60836
# Epoch 27/200
# 400/400 [==============================] - 118s 294ms/step - loss: 0.9214 - accuracy: 0.6423 - val_loss: 1.0880 - val_accuracy: 0.5326
#
# Epoch 00027: val_accuracy did not improve from 0.60836
# Epoch 28/200
# 400/400 [==============================] - 116s 289ms/step - loss: 0.9120 - accuracy: 0.6454 - val_loss: 1.1727 - val_accuracy: 0.4804
#
# Epoch 00028: val_accuracy did not improve from 0.60836
# Epoch 29/200
# 400/400 [==============================] - 114s 284ms/step - loss: 0.8907 - accuracy: 0.6566 - val_loss: 0.9353 - val_accuracy: 0.5901
#
# Epoch 00029: val_accuracy did not improve from 0.60836
# Epoch 30/200
# 400/400 [==============================] - 124s 311ms/step - loss: 0.8786 - accuracy: 0.6637 - val_loss: 0.9535 - val_accuracy: 0.5953
#
# Epoch 00030: val_accuracy did not improve from 0.60836
# Epoch 31/200
# 400/400 [==============================] - 116s 290ms/step - loss: 0.8604 - accuracy: 0.6679 - val_loss: 1.1734 - val_accuracy: 0.4386
#
# Epoch 00031: val_accuracy did not improve from 0.60836
# Epoch 32/200
# 400/400 [==============================] - 120s 301ms/step - loss: 0.8633 - accuracy: 0.6729 - val_loss: 1.0411 - val_accuracy: 0.5509
#
# Epoch 00032: val_accuracy did not improve from 0.60836
# Epoch 33/200
# 400/400 [==============================] - 121s 303ms/step - loss: 0.8491 - accuracy: 0.6741 - val_loss: 1.0169 - val_accuracy: 0.5587
#
# Epoch 00033: val_accuracy did not improve from 0.60836
# Epoch 34/200
# 400/400 [==============================] - 114s 286ms/step - loss: 0.8425 - accuracy: 0.6762 - val_loss: 1.1782 - val_accuracy: 0.4778
#
# Epoch 00034: val_accuracy did not improve from 0.60836
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 35/200
# 400/400 [==============================] - 119s 298ms/step - loss: 0.8145 - accuracy: 0.6926 - val_loss: 1.0082 - val_accuracy: 0.5640
#
# Epoch 00035: val_accuracy did not improve from 0.60836
# Epoch 36/200
# 400/400 [==============================] - 103s 256ms/step - loss: 0.7721 - accuracy: 0.7048 - val_loss: 0.9999 - val_accuracy: 0.5614
#
# Epoch 00036: val_accuracy did not improve from 0.60836
# Epoch 37/200
# 400/400 [==============================] - 70s 176ms/step - loss: 0.7581 - accuracy: 0.7193 - val_loss: 1.1862 - val_accuracy: 0.5039
#
# Epoch 00037: val_accuracy did not improve from 0.60836
# Epoch 38/200
# 400/400 [==============================] - 69s 173ms/step - loss: 0.7555 - accuracy: 0.7135 - val_loss: 0.9849 - val_accuracy: 0.5901
#
# Epoch 00038: val_accuracy did not improve from 0.60836
# Epoch 39/200
# 400/400 [==============================] - 73s 183ms/step - loss: 0.7408 - accuracy: 0.7201 - val_loss: 0.9116 - val_accuracy: 0.6162
#
# Epoch 00039: val_accuracy improved from 0.60836 to 0.61619, saving model to C:\Users\Ricardo Santos\Desktop\Mestrado Ricardo\Ano 1\Spring Semester\Deep\Deep_Learning_Project\CNN_SpermCells\path/Models\AlexNet_RGB.h5
# Epoch 40/200
# 400/400 [==============================] - 75s 188ms/step - loss: 0.7330 - accuracy: 0.7254 - val_loss: 0.9409 - val_accuracy: 0.5692
#
# Epoch 00040: val_accuracy did not improve from 0.61619
# Epoch 41/200
# 400/400 [==============================] - 72s 180ms/step - loss: 0.7274 - accuracy: 0.7272 - val_loss: 1.0165 - val_accuracy: 0.5640
#
# Epoch 00041: val_accuracy did not improve from 0.61619
# Epoch 42/200
# 400/400 [==============================] - 70s 176ms/step - loss: 0.7145 - accuracy: 0.7342 - val_loss: 0.9904 - val_accuracy: 0.6057
#
# Epoch 00042: val_accuracy did not improve from 0.61619
# Epoch 43/200
# 400/400 [==============================] - 75s 187ms/step - loss: 0.7211 - accuracy: 0.7265 - val_loss: 0.8710 - val_accuracy: 0.6319
#
# Epoch 00043: val_accuracy improved from 0.61619 to 0.63185, saving model to C:\Users\Ricardo Santos\Desktop\Mestrado Ricardo\Ano 1\Spring Semester\Deep\Deep_Learning_Project\CNN_SpermCells\path/Models\AlexNet_RGB.h5
# Epoch 44/200
# 400/400 [==============================] - 77s 193ms/step - loss: 0.7020 - accuracy: 0.7384 - val_loss: 1.0507 - val_accuracy: 0.5509
#
# Epoch 00044: val_accuracy did not improve from 0.63185
# Epoch 45/200
# 400/400 [==============================] - 76s 190ms/step - loss: 0.7045 - accuracy: 0.7390 - val_loss: 0.9109 - val_accuracy: 0.6240
#
# Epoch 00045: val_accuracy did not improve from 0.63185
# Epoch 46/200
# 400/400 [==============================] - 75s 188ms/step - loss: 0.6990 - accuracy: 0.7390 - val_loss: 0.8788 - val_accuracy: 0.6580
#
# Epoch 00046: val_accuracy improved from 0.63185 to 0.65796, saving model to C:\Users\Ricardo Santos\Desktop\Mestrado Ricardo\Ano 1\Spring Semester\Deep\Deep_Learning_Project\CNN_SpermCells\path/Models\AlexNet_RGB.h5
# Epoch 47/200
# 400/400 [==============================] - 75s 187ms/step - loss: 0.6803 - accuracy: 0.7514 - val_loss: 1.0061 - val_accuracy: 0.5849
#
# Epoch 00047: val_accuracy did not improve from 0.65796
# Epoch 48/200
# 400/400 [==============================] - 73s 182ms/step - loss: 0.6772 - accuracy: 0.7526 - val_loss: 0.9704 - val_accuracy: 0.6110
#
# Epoch 00048: val_accuracy did not improve from 0.65796
#
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 49/200
# 400/400 [==============================] - 70s 175ms/step - loss: 0.6541 - accuracy: 0.7584 - val_loss: 0.9276 - val_accuracy: 0.5953
#
# Epoch 00049: val_accuracy did not improve from 0.65796
# Epoch 50/200
# 400/400 [==============================] - 71s 178ms/step - loss: 0.6418 - accuracy: 0.7670 - val_loss: 0.8922 - val_accuracy: 0.6371
#
# Epoch 00050: val_accuracy did not improve from 0.65796
# Epoch 51/200
# 400/400 [==============================] - 68s 171ms/step - loss: 0.6279 - accuracy: 0.7756 - val_loss: 0.8486 - val_accuracy: 0.6606
#
# Epoch 00051: val_accuracy improved from 0.65796 to 0.66057, saving model to C:\Users\Ricardo Santos\Desktop\Mestrado Ricardo\Ano 1\Spring Semester\Deep\Deep_Learning_Project\CNN_SpermCells\path/Models\AlexNet_RGB.h5
# Epoch 52/200
# 400/400 [==============================] - 70s 176ms/step - loss: 0.6281 - accuracy: 0.7726 - val_loss: 0.9827 - val_accuracy: 0.5901
#
# Epoch 00052: val_accuracy did not improve from 0.66057
# Epoch 53/200
# 400/400 [==============================] - 73s 183ms/step - loss: 0.6201 - accuracy: 0.7757 - val_loss: 0.9140 - val_accuracy: 0.6345
#
# Epoch 00053: val_accuracy did not improve from 0.66057
# Epoch 54/200
# 400/400 [==============================] - 73s 183ms/step - loss: 0.6157 - accuracy: 0.7804 - val_loss: 0.9013 - val_accuracy: 0.6423
#
# Epoch 00054: val_accuracy did not improve from 0.66057
# Epoch 55/200
# 400/400 [==============================] - 73s 183ms/step - loss: 0.5984 - accuracy: 0.7856 - val_loss: 0.9234 - val_accuracy: 0.6397
#
# Epoch 00055: val_accuracy did not improve from 0.66057
# Epoch 56/200
# 400/400 [==============================] - 76s 189ms/step - loss: 0.6012 - accuracy: 0.7810 - val_loss: 0.9771 - val_accuracy: 0.6292
#
# Epoch 00056: val_accuracy did not improve from 0.66057
#
# Epoch 00056: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 57/200
# 400/400 [==============================] - 63s 158ms/step - loss: 0.5898 - accuracy: 0.7911 - val_loss: 0.8707 - val_accuracy: 0.6554
#
# Epoch 00057: val_accuracy did not improve from 0.66057
# Epoch 58/200
# 400/400 [==============================] - 62s 156ms/step - loss: 0.5680 - accuracy: 0.8022 - val_loss: 0.9096 - val_accuracy: 0.6449
#
# Epoch 00058: val_accuracy did not improve from 0.66057
# Epoch 59/200
# 400/400 [==============================] - 60s 151ms/step - loss: 0.5755 - accuracy: 0.7979 - val_loss: 0.9063 - val_accuracy: 0.6501
#
# Epoch 00059: val_accuracy did not improve from 0.66057
# Epoch 60/200
# 400/400 [==============================] - 66s 164ms/step - loss: 0.5661 - accuracy: 0.8007 - val_loss: 0.8350 - val_accuracy: 0.6893
#
# Epoch 00060: val_accuracy improved from 0.66057 to 0.68930, saving model to C:\Users\Ricardo Santos\Desktop\Mestrado Ricardo\Ano 1\Spring Semester\Deep\Deep_Learning_Project\CNN_SpermCells\path/Models\AlexNet_RGB.h5
# Epoch 61/200
# 400/400 [==============================] - 67s 167ms/step - loss: 0.5555 - accuracy: 0.8066 - val_loss: 0.8707 - val_accuracy: 0.6606
#
# Epoch 00061: val_accuracy did not improve from 0.68930
# Epoch 62/200
# 400/400 [==============================] - 66s 164ms/step - loss: 0.5533 - accuracy: 0.8040 - val_loss: 0.9399 - val_accuracy: 0.6397
#
# Epoch 00062: val_accuracy did not improve from 0.68930
# Epoch 63/200
# 400/400 [==============================] - 64s 159ms/step - loss: 0.5563 - accuracy: 0.8026 - val_loss: 0.9110 - val_accuracy: 0.6606
#
# Epoch 00063: val_accuracy did not improve from 0.68930
# Epoch 64/200
# 400/400 [==============================] - 65s 163ms/step - loss: 0.5459 - accuracy: 0.8113 - val_loss: 0.8373 - val_accuracy: 0.6684
#
# Epoch 00064: val_accuracy did not improve from 0.68930
# Epoch 65/200
# 400/400 [==============================] - 63s 158ms/step - loss: 0.5447 - accuracy: 0.8121 - val_loss: 0.8996 - val_accuracy: 0.6606
#
# Epoch 00065: val_accuracy did not improve from 0.68930
#
# Epoch 00065: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 66/200
# 400/400 [==============================] - 63s 158ms/step - loss: 0.5407 - accuracy: 0.8119 - val_loss: 0.8876 - val_accuracy: 0.6527
#
# Epoch 00066: val_accuracy did not improve from 0.68930
# Epoch 67/200
# 400/400 [==============================] - 59s 146ms/step - loss: 0.5321 - accuracy: 0.8165 - val_loss: 0.8535 - val_accuracy: 0.6762
#
# Epoch 00067: val_accuracy did not improve from 0.68930
# Epoch 68/200
# 400/400 [==============================] - 59s 147ms/step - loss: 0.5349 - accuracy: 0.8149 - val_loss: 0.8837 - val_accuracy: 0.6658
#
# Epoch 00068: val_accuracy did not improve from 0.68930
# Epoch 69/200
# 400/400 [==============================] - 65s 162ms/step - loss: 0.5198 - accuracy: 0.8247 - val_loss: 0.8885 - val_accuracy: 0.6736
#
# Epoch 00069: val_accuracy did not improve from 0.68930
# Epoch 70/200
# 400/400 [==============================] - 61s 152ms/step - loss: 0.5229 - accuracy: 0.8218 - val_loss: 0.8558 - val_accuracy: 0.6736
#
# Epoch 00070: val_accuracy did not improve from 0.68930
#
# Epoch 00070: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# Epoch 71/200
# 400/400 [==============================] - 66s 164ms/step - loss: 0.5147 - accuracy: 0.8245 - val_loss: 0.8918 - val_accuracy: 0.6632
#
# Epoch 00071: val_accuracy did not improve from 0.68930
# Epoch 72/200
# 400/400 [==============================] - 66s 166ms/step - loss: 0.5303 - accuracy: 0.8192 - val_loss: 0.8841 - val_accuracy: 0.6684
#
# Epoch 00072: val_accuracy did not improve from 0.68930
# Epoch 73/200
# 400/400 [==============================] - 63s 158ms/step - loss: 0.5072 - accuracy: 0.8270 - val_loss: 0.8681 - val_accuracy: 0.6684
#
# Epoch 00073: val_accuracy did not improve from 0.68930
# Epoch 74/200
# 400/400 [==============================] - 67s 168ms/step - loss: 0.5099 - accuracy: 0.8256 - val_loss: 0.8676 - val_accuracy: 0.6815
#
# Epoch 00074: val_accuracy did not improve from 0.68930
# Epoch 75/200
# 400/400 [==============================] - 65s 161ms/step - loss: 0.5104 - accuracy: 0.8289 - val_loss: 0.8408 - val_accuracy: 0.6815
#
# Epoch 00075: val_accuracy did not improve from 0.68930
#
# Epoch 00075: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# Epoch 76/200
# 400/400 [==============================] - 64s 161ms/step - loss: 0.5010 - accuracy: 0.8330 - val_loss: 0.8565 - val_accuracy: 0.6841
#
# Epoch 00076: val_accuracy did not improve from 0.68930
# Epoch 77/200
# 400/400 [==============================] - 63s 158ms/step - loss: 0.5107 - accuracy: 0.8236 - val_loss: 0.8675 - val_accuracy: 0.6736
#
# Epoch 00077: val_accuracy did not improve from 0.68930
# Epoch 78/200
# 400/400 [==============================] - 60s 151ms/step - loss: 0.5083 - accuracy: 0.8258 - val_loss: 0.8788 - val_accuracy: 0.6606
#
# Epoch 00078: val_accuracy did not improve from 0.68930
# Epoch 79/200
# 400/400 [==============================] - 60s 150ms/step - loss: 0.5076 - accuracy: 0.8268 - val_loss: 0.8561 - val_accuracy: 0.6841
#
# Epoch 00079: val_accuracy did not improve from 0.68930
# Epoch 80/200
# 400/400 [==============================] - 62s 156ms/step - loss: 0.5156 - accuracy: 0.8204 - val_loss: 0.8649 - val_accuracy: 0.6736
#
# Epoch 00080: val_accuracy did not improve from 0.68930
#
# Epoch 00080: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# Restoring model weights from the end of the best epoch.
# Epoch 00080: early stopping

# %% [markdown]
# #### 4.5 Evaluate  model

# %%
_, train_acc = AlexNet.evaluate(Alex_training, verbose=1)
_, val_acc = AlexNet.evaluate(Alex_val, verbose=1)
print('Train: %.3f, Val: %.3f' % (train_acc, val_acc))

# plot training history
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='val')
plt.legend()
plt.show()
# Out:
# 400/400 [==============================] - 25s 62ms/step - loss: 0.5125 - accuracy: 0.8270
# 6/6 [==============================] - 0s 29ms/step - loss: 0.8350 - accuracy: 0.6893
# Train: 0.827, Val: 0.689

# %%
test_loss, test_acc = AlexNet.evaluate(Alex_test)

print('Test loss:', test_loss)
print('Test accuracy:', test_acc)
print("\nTime:",sum(cb.logs)/60,"min")
# Out:
# 130/130 [==============================] - 3s 20ms/step - loss: 0.8124 - accuracy: 0.6846
# Test loss: 0.8124385476112366
# Test accuracy: 0.6846153736114502
#
# Time: 117.56138950333337 min

# %% [markdown]
# #### 4.5 Make Predictions

# %%
#get predicted probality
prediction = AlexNet.predict(Alex_test,verbose=1)

#Get class of prediction
predicted_class = np.argmax(prediction,axis=1)

#get trueclass
true_classes = Alex_test.classes

# get names of pictures
filenames = Alex_test.filenames

#store info in dataframe
alex_predictions = pd.DataFrame({'Filename': filenames, 'Label': true_classes, 'AlexNet': predicted_class})
# Out:
# 130/130 [==============================] - 3s 18ms/step

# %%
Alex_pred =  pd.DataFrame(prediction, columns = ['Class 0', 'Class 1', 'Class 2', 'Class 3'], index = filenames)

Alex_pred.to_csv(path+'/Models/Alex_pred_prob.csv')

Alex_pred
# Out:
#                                           Class 0   Class 1   Class 2  \
# class0\ch00_p1-pl2-sample1-sperm10.tif   0.011690  0.050559  0.095833
# class0\ch00_p1-pl2-sample13-sperm11.tif  0.048713  0.814292  0.008872
# class0\ch00_p1-pl2-sample4-sperm7.tif    0.008627  0.128375  0.184083
# class0\ch00_p1-pl2-sample8-sperm6.tif    0.001701  0.303976  0.011616
# class0\ch00_p1-pl2-sample9-sperm9.tif    0.055217  0.657697  0.021282
# ...                                           ...       ...       ...
# class3\image_020.BMP                     0.010086  0.002832  0.980090
# class3\image_038.BMP                     0.934542  0.009350  0.005195
# class3\image_041.BMP                     0.030607  0.074045  0.582012
# class3\image_049.BMP                     0.344542  0.262017  0.218231
# class3\image_051.BMP                     0.001372  0.001817  0.013935
#
#                                           Class 3
# class0\ch00_p1-pl2-sample1-sperm10.tif   0.841918
# class0\ch00_p1-pl2-sample13-sperm11.tif  0.128123
# class0\ch00_p1-pl2-sample4-sperm7.tif    0.678916
# class0\ch00_p1-pl2-sample8-sperm6.tif    0.682707
# class0\ch00_p1-pl2-sample9-sperm9.tif    0.265804
# ...                                           ...
# class3\image_020.BMP                     0.006993
# class3\image_038.BMP                     0.050913
# class3\image_041.BMP                     0.313336
# class3\image_049.BMP                     0.175209
# class3\image_051.BMP                     0.982876
#
# [130 rows x 4 columns]

# %%
alex_predictions
# Out:
#                                     Filename  Label  AlexNet
# 0     class0\ch00_p1-pl2-sample1-sperm10.tif      0        3
# 1    class0\ch00_p1-pl2-sample13-sperm11.tif      0        1
# 2      class0\ch00_p1-pl2-sample4-sperm7.tif      0        3
# 3      class0\ch00_p1-pl2-sample8-sperm6.tif      0        3
# 4      class0\ch00_p1-pl2-sample9-sperm9.tif      0        1
# ..                                       ...    ...      ...
# 125                     class3\image_020.BMP      3        2
# 126                     class3\image_038.BMP      3        0
# 127                     class3\image_041.BMP      3        2
# 128                     class3\image_049.BMP      3        0
# 129                     class3\image_051.BMP      3        3
#
# [130 rows x 3 columns]

# %% [markdown]
# #### 4.7  Confusion matrix and classification report

# %%
def metrics(y_train, pred_train , y_val, pred_val):
    print('___________________________________________________________________________________________________________')
    print('                                                     TRAIN                                                 ')
    print('----------------------------------------------------------------------------------------------------------')
    print(classification_report(y_train, pred_train))
    print(confusion_matrix(y_train, pred_train))


    print('___________________________________________________________________________________________________________')
    print('                                                VALIDATION                                                 ')
    print('-----------------------------------------------------------------------------------------------------------')
    print(classification_report(y_val, pred_val))
    print(confusion_matrix(y_val, pred_val))

# %%
train_labels, val_labels = Alex_training.classes, Alex_val.classes
pred_train, pred_val = np.argmax(AlexNet.predict(Alex_training), axis = 1), np.argmax(AlexNet.predict(Alex_val), axis = 1)

metrics(train_labels, pred_train , val_labels, pred_val)
# Out:
# ___________________________________________________________________________________________________________
#                                                      TRAIN
# ----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.26      0.27      0.26      6400
#            1       0.25      0.28      0.26      6400
#            2       0.25      0.26      0.26      6400
#            3       0.25      0.20      0.22      6400
#
#     accuracy                           0.25     25600
#    macro avg       0.25      0.25      0.25     25600
# weighted avg       0.25      0.25      0.25     25600
#
# [[1736 1832 1620 1212]
#  [1673 1782 1657 1288]
#  [1699 1806 1667 1228]
#  [1659 1806 1674 1261]]
# ___________________________________________________________________________________________________________
#                                                 VALIDATION
# -----------------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.10      0.11      0.11        46
#            1       0.16      0.19      0.17        84
#            2       0.13      0.20      0.16        40
#            3       0.56      0.46      0.51       213
#
#     accuracy                           0.33       383
#    macro avg       0.24      0.24      0.24       383
# weighted avg       0.37      0.33      0.35       383
#
# [[ 5 15  7 19]
#  [12 16 16 40]
#  [ 8  7  8 17]
#  [24 61 30 98]]

# %%
class_labels = list(Alex_test.class_indices.keys())   

print(confusion_matrix(true_classes, predicted_class))

report = classification_report(true_classes, predicted_class, target_names=class_labels)
print(report)
# Out:
# [[ 2  4  2  8]
#  [ 4  5  6 14]
#  [ 2  6  1  5]
#  [12 20 10 29]]
#               precision    recall  f1-score   support
#
#       class0       0.10      0.12      0.11        16
#       class1       0.14      0.17      0.16        29
#       class2       0.05      0.07      0.06        14
#       class3       0.52      0.41      0.46        71
#
#     accuracy                           0.28       130
#    macro avg       0.20      0.19      0.20       130
# weighted avg       0.33      0.28      0.30       130

# %% [markdown]
# ### ROC CURVES AND PRECISION RECALL

# %%
#VAL DATA

y_pred = AlexNet.predict(Alex_val)
y_real = val_labels

# %%
from sklearn.preprocessing import label_binarize
# Binarize the output
y_real = label_binarize(y_real, classes=[0, 1, 2, 3])
#y_pred = label_binarize(y_pred, classes=[0, 1, 2, 3])
n_classes = y_real.shape[1]

# %%
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(4):
    fpr[i], tpr[i], _ = roc_curve(y_real[:, i], y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_real.ravel(), y_pred.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# %%
lw=2


# First aggregate all false positive rates
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

# Plot all ROC curves
plt.rcParams.update({'font.size': 16})
plt.figure(figsize=(8, 8))
plt.plot(fpr["micro"], tpr["micro"],
         label='micro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["micro"]),
         color='deeppink', linestyle=':', linewidth=4)

#plt.plot(fpr["macro"], tpr["macro"],
         #label='macro-average ROC curve (area = {0:0.2f})'
               #''.format(roc_auc["macro"]),
         #color='navy', linestyle=':', linewidth=4)

colors = cycle(['navy', 'turquoise', 'darkorange', 'cornflowerblue', 'teal'])

for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc="lower right")
plt.legend(loc=(1.2, 0.67), prop=dict(size=14), frameon=False)

#make it pretty
for pos in ['right', 'top']:
    plt.gca().spines[pos].set_visible(False)

plt.show()
# Out:
# <ipython-input-23-70844e3c8198>:10: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
#   mean_tpr += interp(all_fpr, fpr[i], tpr[i])

# %%
#PRecision Recall

# For each class
precision = dict()
recall = dict()
average_precision = dict()
for i in range(n_classes):
    precision[i], recall[i], _ = precision_recall_curve(y_real[:, i],
                                                        y_pred[:, i])
    average_precision[i] = average_precision_score(y_real[:, i], y_pred[:, i])

# A "micro-average": quantifying score on all classes jointly
precision["micro"], recall["micro"], _ = precision_recall_curve(y_real.ravel(), y_pred.ravel())
average_precision["micro"] = average_precision_score(y_real, y_pred,
                                                     average="micro")
print('Average precision score, micro-averaged over all classes: {0:0.2f}'
      .format(average_precision["micro"]))
# Out:
# Average precision score, micro-averaged over all classes: 0.33

# %%
# setup plot details
colors = cycle(['navy', 'turquoise', 'darkorange', 'cornflowerblue', 'teal'])

plt.figure(figsize=(8, 8))
f_scores = np.linspace(0.2, 0.8, num=4)
lines = []
labels = []
for f_score in f_scores:
    x = np.linspace(0.01, 1)
    y = f_score * x / (2 * x - f_score)
    l, = plt.plot(x[y >= 0], y[y >= 0], color='gray', alpha=0.2)
    plt.annotate('f1={0:0.1f}'.format(f_score), xy=(0.9, y[45] + 0.02))

lines.append(l)
labels.append('iso-f1 curves')
l, = plt.plot(recall["micro"], precision["micro"], color='gold', lw=2)
lines.append(l)
labels.append('micro-average Precision-recall (area = {0:0.2f})'
              ''.format(average_precision["micro"]))

for i, color in zip(range(n_classes), colors):
    l, = plt.plot(recall[i], precision[i], color=color, lw=2)
    lines.append(l)
    labels.append('Precision-recall for class {0} (area = {1:0.2f})'.format(i, average_precision[i]))
    
#plot
fig = plt.gcf()
fig.subplots_adjust(bottom=0.25)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('Recall (Positive Predictive Value)')
plt.ylabel('Precision (True Positive Rate)')
plt.title('Precision-Recall Curve')
plt.legend(lines, labels, loc=(1, 0.67), prop=dict(size=14), frameon=False)

#make it pretty
for pos in ['right', 'top']:
    plt.gca().spines[pos].set_visible(False)


plt.show()

# %% [markdown]
# ## Test Data

# %%
#VAL DATA

y_pred = prediction
y_real = true_classes

# %%
from sklearn.preprocessing import label_binarize
# Binarize the output
y_real = label_binarize(y_real, classes=[0, 1, 2, 3])
#y_pred = label_binarize(y_pred, classes=[0, 1, 2, 3])
n_classes = y_real.shape[1]

# %%
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(4):
    fpr[i], tpr[i], _ = roc_curve(y_real[:, i], y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_real.ravel(), y_pred.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# %%
lw=2


# First aggregate all false positive rates
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

# Plot all ROC curves
plt.rcParams.update({'font.size': 16})
plt.figure(figsize=(8, 8))
plt.plot(fpr["micro"], tpr["micro"],
         label='micro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["micro"]),
         color='deeppink', linestyle=':', linewidth=4)

#plt.plot(fpr["macro"], tpr["macro"],
         #label='macro-average ROC curve (area = {0:0.2f})'
               #''.format(roc_auc["macro"]),
         #color='navy', linestyle=':', linewidth=4)

colors = cycle(['navy', 'turquoise', 'darkorange', 'cornflowerblue', 'teal'])

for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc="lower right")
plt.legend(loc=(1.2, 0.67), prop=dict(size=14), frameon=False)

#make it pretty
for pos in ['right', 'top']:
    plt.gca().spines[pos].set_visible(False)

plt.show()
# Out:
# <ipython-input-29-70844e3c8198>:10: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
#   mean_tpr += interp(all_fpr, fpr[i], tpr[i])

# %% [markdown]
# ### Precision-Recall Curve

# %%
#PRecision Recall

# For each class
precision = dict()
recall = dict()
average_precision = dict()
for i in range(n_classes):
    precision[i], recall[i], _ = precision_recall_curve(y_real[:, i],
                                                        y_pred[:, i])
    average_precision[i] = average_precision_score(y_real[:, i], y_pred[:, i])

# A "micro-average": quantifying score on all classes jointly
precision["micro"], recall["micro"], _ = precision_recall_curve(y_real.ravel(), y_pred.ravel())
average_precision["micro"] = average_precision_score(y_real, y_pred,
                                                     average="micro")
print('Average precision score, micro-averaged over all classes: {0:0.2f}'
      .format(average_precision["micro"]))
# Out:
# Average precision score, micro-averaged over all classes: 0.28

# %%
# setup plot details
colors = cycle(['navy', 'turquoise', 'darkorange', 'cornflowerblue', 'teal'])

plt.figure(figsize=(8, 8))
f_scores = np.linspace(0.2, 0.8, num=4)
lines = []
labels = []
for f_score in f_scores:
    x = np.linspace(0.01, 1)
    y = f_score * x / (2 * x - f_score)
    l, = plt.plot(x[y >= 0], y[y >= 0], color='gray', alpha=0.2)
    plt.annotate('f1={0:0.1f}'.format(f_score), xy=(0.9, y[45] + 0.02))

lines.append(l)
labels.append('iso-f1 curves')
l, = plt.plot(recall["micro"], precision["micro"], color='gold', lw=2)
lines.append(l)
labels.append('micro-average Precision-recall (area = {0:0.2f})'
              ''.format(average_precision["micro"]))

for i, color in zip(range(n_classes), colors):
    l, = plt.plot(recall[i], precision[i], color=color, lw=2)
    lines.append(l)
    labels.append('Precision-recall for class {0} (area = {1:0.2f})'.format(i, average_precision[i]))
    
#plot
fig = plt.gcf()
fig.subplots_adjust(bottom=0.25)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('Recall (Positive Predictive Value)')
plt.ylabel('Precision (True Positive Rate)')
plt.title('Precision-Recall Curve')
plt.legend(lines, labels, loc=(1, 0.67), prop=dict(size=14), frameon=False)

#make it pretty
for pos in ['right', 'top']:
    plt.gca().spines[pos].set_visible(False)


plt.show()
